# %% [markdown]
# # Libraries and data loading

# %%
from io import open
import os
import re
import random
import xml.etree.ElementTree as ET

import gensim.downloader as api

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import numpy as np
from torch.utils.data import TensorDataset, DataLoader, RandomSampler

import torch
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import nltk
nltk.download('punkt')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !wget https://object.pouta.csc.fi/OPUS-wikimedia/v20230407/tmx/af-en.tmx.gz
# !gunzip af-en.tmx.gz
# Out:
# --2024-07-21 12:39:09--  https://object.pouta.csc.fi/OPUS-wikimedia/v20230407/tmx/af-en.tmx.gz
# Resolving object.pouta.csc.fi (object.pouta.csc.fi)... 86.50.254.18, 86.50.254.19
# Connecting to object.pouta.csc.fi (object.pouta.csc.fi)|86.50.254.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9645824 (9.2M) [application/gzip]
# Saving to: ‘af-en.tmx.gz’
#
# af-en.tmx.gz        100%[===================>]   9.20M  3.74MB/s    in 2.5s
#
# 2024-07-21 12:39:13 (3.74 MB/s) - ‘af-en.tmx.gz’ saved [9645824/9645824]

# %%
# !unzip ee_mt.v0.1.zip
# Out:
# Archive:  /content/ee_mt.v0.1.zip
#    creating: ee_mt.v0.1/
#    creating: ee_mt.v0.1/train/
#   inflating: ee_mt.v0.1/train/data414_2020_a1.af.txt
#   inflating: ee_mt.v0.1/train/data414_2020_a1.en.txt
#   inflating: ee_mt.v0.1/train/data414_2021_a1.af.txt
#   inflating: ee_mt.v0.1/train/data414_2021_a1.en.txt
#   inflating: ee_mt.v0.1/train/data414_2021_a2.af.txt
#   inflating: ee_mt.v0.1/train/data414_2021_a2.en.txt
#   inflating: ee_mt.v0.1/train/ss414_2018_a1.af.txt
#   inflating: ee_mt.v0.1/train/ss414_2018_a1.en.txt
#   inflating: ee_mt.v0.1/train/ss414_2018_a2.af.txt
#   inflating: ee_mt.v0.1/train/ss414_2018_a2.en.txt
#   inflating: ee_mt.v0.1/train/ss414_2018_a3.af.txt
#   inflating: ee_mt.v0.1/train/ss414_2018_a3.en.txt
#   inflating: ee_mt.v0.1/train/ss414_2019_a1.af.txt
#   inflating: ee_mt.v0.1/train/ss414_2019_a1.en.txt
#   inflating: ee_mt.v0.1/train/ss414_2019_a2.af.txt
#   inflating: ee_mt.v0.1/train/ss414_2019_a2.en.txt
#   inflating: ee_mt.v0.1/train/ss414_2019_a3.af.txt
#   inflating: ee_mt.v0.1/train/ss414_2019_a3.en.txt
#    creating: ee_mt.v0.1/val/
#   inflating: ee_mt.v0.1/val/compsys414_2017_a1.af.txt
#   inflating: ee_mt.v0.1/val/compsys414_2017_a1.en.txt
#   inflating: ee_mt.v0.1/val/compsys414_2017_a2.af.txt
#   inflating: ee_mt.v0.1/val/compsys414_2017_a2.en.txt
#   inflating: ee_mt.v0.1/val/compsys414_2017_a3.af.txt
#   inflating: ee_mt.v0.1/val/compsys414_2017_a3.en.txt

# %% [markdown]
# # Data Prep

# %%
SOS_token = 0
EOS_token = 1
MAX_LENGTH = 30

# %%
word2vec_model = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
class lang_attr:
  def __init__(self):
    self.word2index = {}
    self.word_count = {}
    self.index2word = {0: "SOS", 1: "EOS"}
    self.n_words = 2

  def add_sentence(self, sentence):
    for word in sentence.split(' '):
      self.add_word(word)

  def add_word(self, word):
    if word not in self.word2index:
      self.word2index[word] = self.n_words
      self.index2word[self.n_words] = word
      self.word_count[word] = 1
      self.n_words += 1
    else:
      self.word_count[word] += 1

# %%
def read_file_lines(file_path):
  with open(file_path, 'r', encoding='utf-8') as file:
    return [line for line in file.readlines() if not line.startswith('%')]

def read_text_files(input_folder):
  afr = []
  eng = []

  for root, dirs, files in os.walk(input_folder):
    for file in files:
      if file.endswith('.af.txt'):
        af_file_path = os.path.join(root, file)
        en_file_path = af_file_path.replace('.af.txt', '.en.txt')

        if os.path.exists(en_file_path):
          af_sentences = read_file_lines(af_file_path)
          en_sentences = read_file_lines(en_file_path)

          if len(af_sentences) == len(en_sentences):
            afr.extend(af_sentences)
            eng.extend(en_sentences)
          else:
            print(f"Warning: {af_file_path} and {en_file_path} have different number of lines.")

  return afr, eng

def read_xml(file_path):
  tree = ET.parse(file_path)
  root = tree.getroot()
  namespaces = {'xml': 'http://www.w3.org/XML/1998/namespace'}

  afr = []
  eng = []

  for tu in root.findall('.//tu'):
    afrikaans_text = tu.find(".//tuv[@xml:lang='af']/seg", namespaces).text
    english_text = tu.find(".//tuv[@xml:lang='en']/seg", namespaces).text
    afr.append(afrikaans_text)
    eng.append(english_text)

  return afr, eng

def normalise(sentence):
  s = sentence.lower().strip()
  s = re.sub(r"[^a-zA-Z\s]", "", s)
  s = re.sub(r"\s+", " ", s)
  return s.strip()

def create_pairs(afr, eng):
  pairs = [[normalise(eng[i]), normalise(afr[i])] for i in range(len(afr)) if eng[i] is not None and afr[i] is not None]
  pairs = [pair for pair in pairs if len(pair[0].split(' ')) < MAX_LENGTH and len(pair[1].split(' ')) < MAX_LENGTH]
  return pairs

# %%
def process_data(xml_file_path=None):
  # Get online data
  afr, eng = read_xml(xml_file_path)
  # Get provided data
  afr_1, eng_1 = read_text_files("ee_mt.v0.1/train")
  afr.extend(afr_1)
  eng.extend(eng_1)

  pairs = create_pairs(afr, eng)
  pairs = [pair for pair in pairs if pair[0] != "" and pair[1] != ""]

  input_lang = lang_attr() # Afrikaans
  output_lang = lang_attr() # English
  for pair in pairs:
    input_lang.add_sentence(pair[0])
    output_lang.add_sentence(pair[1])

  return input_lang, output_lang, pairs

def index_sentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ') if word in lang.word2index]

def get_dataloader(batch_size, xml_file_path=None):
  input_lang, output_lang, pairs = process_data(xml_file_path=xml_file_path)
  n = len(pairs)
  all_input_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)
  all_target_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)

  for idx, (input, target) in enumerate(pairs):
    input_ids = index_sentence(input_lang, input)
    target_ids = index_sentence(output_lang, target)
    input_ids.append(EOS_token)
    target_ids.append(EOS_token)
    all_input_ids[idx, :len(input_ids)] = input_ids
    all_target_ids[idx, :len(target_ids)] = target_ids

  train_data = TensorDataset(torch.LongTensor(all_input_ids).to(device), torch.LongTensor(all_target_ids).to(device))
  train_sampler = RandomSampler(train_data)
  train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
  return input_lang, output_lang, pairs, train_dataloader

# %% [markdown]
# # RNN

# %% [markdown]
# ### Encoder using pre-trained embeddings

# %%
class EncoderRNN(nn.Module):
  def __init__(self, input_size, hidden_size, embedding_matrix, dropout_prob=0.1):
    super(EncoderRNN, self).__init__()
    self.hidden_size = hidden_size

    self.embedding = nn.Embedding(input_size, hidden_size)
    self.embedding.weight = nn.Parameter(torch.tensor(embedding_matrix, dtype=torch.float32))
    self.embedding.weight.requires_grad = True

    self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
    self.dropout = nn.Dropout(dropout_prob)

  def forward(self, input):
    embedded = self.dropout(self.embedding(input))
    output, hidden = self.gru(embedded)
    return output, hidden

# %% [markdown]
# ### Encoder not using pre-trained embeddings

# %%
class EncoderRNN(nn.Module):
  def __init__(self, input_size, hidden_size, dropout_prob=0.1):
    super(EncoderRNN, self).__init__()
    self.hidden_size = hidden_size

    self.embedding = nn.Embedding(input_size, hidden_size)
    self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
    self.dropout = nn.Dropout(dropout_prob)

  def forward(self, input):
    embedded = self.dropout(self.embedding(input))
    output, hidden = self.gru(embedded)
    return output, hidden

# %% [markdown]
# ### Decoder using Bahdanau attention

# %%
class BahdanauAttention(nn.Module):
  def __init__(self, hidden_size):
    super(BahdanauAttention, self).__init__()
    self.Wa = nn.Linear(hidden_size, hidden_size)
    self.Ua = nn.Linear(hidden_size, hidden_size)
    self.Va = nn.Linear(hidden_size, 1)

  def forward(self, query, keys):
    scores = self.Va(torch.tanh(self.Wa(query) + self.Ua(keys)))
    scores = scores.squeeze(2).unsqueeze(1)

    weights = F.softmax(scores, dim=-1)
    context = torch.bmm(weights, keys)

    return context, weights

class AttnDecoderRNN(nn.Module):
  def __init__(self, hidden_size, output_size, dropout_prob=0.3):
    super(AttnDecoderRNN, self).__init__()
    self.embedding = nn.Embedding(output_size, hidden_size)
    self.attention = BahdanauAttention(hidden_size)
    self.gru = nn.GRU(2 * hidden_size, hidden_size, batch_first=True)
    self.out = nn.Linear(hidden_size, output_size)
    self.dropout = nn.Dropout(dropout_prob)

  def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
    batch_size = encoder_outputs.size(0)
    decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
    decoder_hidden = encoder_hidden
    decoder_outputs = []
    attentions = []

    for i in range(MAX_LENGTH):
      decoder_output, decoder_hidden, attn_weights = self.forward_step(decoder_input,
                                                    decoder_hidden, encoder_outputs)
      decoder_outputs.append(decoder_output)
      attentions.append(attn_weights)

      if target_tensor is not None:
        decoder_input = target_tensor[:, i].unsqueeze(1)
      else:
        _, topi = decoder_output.topk(1)
        decoder_input = topi.squeeze(-1).detach()

    decoder_outputs = torch.cat(decoder_outputs, dim=1)
    decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
    attentions = torch.cat(attentions, dim=1)

    return decoder_outputs, decoder_hidden, attentions


  def forward_step(self, input, hidden, encoder_outputs):
    embedded =  self.dropout(self.embedding(input))

    query = hidden.permute(1, 0, 2)
    context, attn_weights = self.attention(query, encoder_outputs)
    input_gru = torch.cat((embedded, context), dim=2)

    output, hidden = self.gru(input_gru, hidden)
    output = self.out(output)

    return output, hidden, attn_weights

# %% [markdown]
# # Training

# %%
def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion):

  total_loss = 0
  for data in dataloader:
    input_tensor, target_tensor = data

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    encoder_outputs, encoder_hidden = encoder(input_tensor)
    decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

    loss = criterion(
      decoder_outputs.view(-1, decoder_outputs.size(-1)),
      target_tensor.view(-1)
    )
    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    total_loss += loss.item()

  return total_loss / len(dataloader)

# %%
def train(dataloader, encoder, decoder, n_epochs, learning_rate=0.001):
    loss_history = []
    total_loss = 0

    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()

    for epoch in range(1, n_epochs + 1):
        total_loss += train_epoch(dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)

        if epoch % 5 == 0:
            avg_loss = total_loss / 5
            loss_history.append(avg_loss)
            total_loss = 0
            print(f'** Epoch: {epoch} ** Avg Loss: {avg_loss} ** {epoch / n_epochs * 100}%')
        if epoch == 1:
            avg_loss = total_loss
            print(f'** Epoch: {epoch} ** Avg Loss: {avg_loss} ** {epoch / n_epochs * 100}%')

    return loss_history

# %% [markdown]
# # Training without pre-trained embeddings

# %%
hidden_size = 300
batch_size = 150

input_lang, output_lang, pairs, train_dataloader = get_dataloader(batch_size, xml_file_path="af-en.tmx")

encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)

loss_history = train(train_dataloader, encoder, decoder, 10)

# %% [markdown]
# ## Evaluation

# %%
def evaluate(encoder, decoder, sentence, input_lang, output_lang):
    with torch.no_grad():
        input_index = index_sentence(input_lang, sentence)
        input_index.append(EOS_token)
        input_tensor = torch.tensor(input_index, dtype=torch.long, device=device).view(1, -1)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            decoded_words.append(output_lang.index2word[idx.item()])
    return decoded_words, decoder_attn

# %%
def evaluateRandomly(encoder, decoder, n=1):
    for i in range(n):
        pair = random.choice(pairs)
        print('English:', pair[0])
        print('Afrikaans (True):', pair[1])
        output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
        output_sentence = ' '.join(output_words)
        print('Afrikaans (Predicted):', output_sentence)
        print('')

# %%
def calculate_blue_test(encoder, decoder):
  smoothing_function = SmoothingFunction().method1
  total_bleu_score = 0.0

  for pair in pairs:
    reference = nltk.word_tokenize(pair[1])
    output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
    candidate = output_words[:-1]  # Exclude the <EOS> token
    bleu_score = sentence_bleu([reference], candidate, smoothing_function=smoothing_function)
    total_bleu_score += bleu_score

  average_bleu_score = total_bleu_score / len(pairs)
  print(f'\nAverage BLEU score for {len(pairs)} sentences: {average_bleu_score:.4f}')

# %%
def calculate_blue_val(encoder, decoder):
    afr, eng = read_text_files("ee_mt.v0.1/val")
    afr = [normalise(sentence) for sentence in afr]
    eng = [normalise(sentence) for sentence in eng]
    smoothing_function = SmoothingFunction().method1
    total_bleu_score = 0.0

    for i in range(len(afr)):
        reference = nltk.word_tokenize(afr[i])
        output_words, _ = evaluate(encoder, decoder, eng[i], input_lang, output_lang)
        candidate = output_words[:-1]  # Exclude the <EOS> token
        bleu_score = sentence_bleu([reference], candidate, smoothing_function=smoothing_function)
        total_bleu_score += bleu_score

    average_bleu_score = total_bleu_score / len(afr)
    print(f'\nAverage BLEU score for {len(afr)} sentences: {average_bleu_score:.4f}')

# %%
encoder.eval()
decoder.eval()
calculate_blue_test(encoder, decoder)
# Out:
# Average BLEU score for 36689 sentences: 0.4758

# %%
encoder.eval()
decoder.eval()
calculate_blue_val(encoder, decoder)
# Out:
# Average BLEU score for 182 sentences: 0.1383

# %% [markdown]
# # Training with pre-trained embeddings

# %%
def create_embedding_matrix(word2vec_model, vocab, embedding_dim):
    embedding_matrix = np.zeros((len(vocab)+2, embedding_dim))
    for word, index in vocab.items():
        if word in word2vec_model:
            embedding_matrix[index] = word2vec_model[word]
        else:
            embedding_matrix[index] = np.random.normal(scale=0.6, size=(embedding_dim,))
    return embedding_matrix

batch_size = 150
input_lang, output_lang, pairs, train_dataloader = get_dataloader(batch_size, xml_file_path="af-en.tmx")

embedding_dim = word2vec_model.vector_size
embedding_matrix = create_embedding_matrix(word2vec_model, output_lang.word2index, embedding_dim)
hidden_size = embedding_dim

# %%
encoder = EncoderRNN(input_lang.n_words, hidden_size, embedding_matrix).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)
loss_history = train(train_dataloader, encoder, decoder, 10)

# %% [markdown]
# ## Evaluation

# %%
encoder.eval()
decoder.eval()
calculate_blue_test(encoder, decoder)
# Out:
# Average BLEU score for 53946 sentences: 0.4868

# %%
encoder.eval()
decoder.eval()
calculate_blue_val(encoder, decoder)
# Out:
# Average BLEU score for 182 sentences: 0.1594

# %%
def print_val(encoder, decoder):
    afr, eng = read_text_files("ee_mt.v0.1/val")
    afr = [normalise(sentence) for sentence in afr]
    eng = [normalise(sentence) for sentence in eng]

    for i in range(len(afr)):
          print('English:', eng[i])
          print('Afrikaans (True):', afr[i])
          output_words, _ = evaluate(encoder, decoder, eng[i], input_lang, output_lang)
          output_sentence = ' '.join(output_words)
          print('Afrikaans (Predicted):', output_sentence)
          print('')

# %%
encoder.eval()
decoder.eval()
print_val(encoder, decoder)
# Out:
# English: a cpu is connected to multiple peripherals through a cpu bus
# Afrikaans (True): n sve is verbind aan verskeie randapparatuur deur n sve bus
# Afrikaans (Predicted): n is met verskeie roterende deur n selfverslag gedra met behulp van n waarskuwing <EOS>
#
# English: a computer system has the following content within its main memory
# Afrikaans (True): n rekenaarstelsel het die volgende inhoud in sy hoof geheue
# Afrikaans (Predicted): n rekenaar toon die volgende inhoud van die orde in die toekoms uit sy orde bepaal <EOS>
#
# English: the efmzg is a arm cortexm platform
# Afrikaans (True): die efmzg is n arm cortexm platform
# Afrikaans (Predicted): die fontein wat in die enjinblok van die platform verteenwoordig word <EOS>
#
# English: below is the ordering options within this family
# Afrikaans (True): die bestelling opsies binne die familie word gesien hieronder
# Afrikaans (Predicted): onder hierdie verbod is hierdie paaie in hierdie gesin <EOS>
#
# English: the efmzg has a number of different power management settings
# Afrikaans (True): die efmzg het n aantal verskillende kragbestuur verstellings
# Afrikaans (Predicted): het n aantal verskillende vorms in voertuie gebring <EOS>
#
# English: below is a table from the manual with the transition times between energy modes
# Afrikaans (True): hieronder is n table vanaf die gids met die oorgangstye tussen verskillende energie modusse
# Afrikaans (Predicted): onder n aantal van die bak met die oorgang van die tydperk tussen die ontwikkeling van die omstandighede <EOS>
#
# English: the functional block diagram of the efmzg is shown below
# Afrikaans (True): die funksionele blokdiagram van die efmzg word gewys hieronder
# Afrikaans (Predicted): diagram van die is getoon onder soos <EOS>
#
# English: a network uses fixed priority arbitration with pe highest and pe lowest priority and a byte takes ms to move between any two processing elements pes over the bus
# Afrikaans (True): n netwerk gebruik vaste prioriteit arbitrasie met pe hoogste en pe laagste prioriteit en n greep neem ms om tussen enige twee verwerkings eenhede ves te beweeg oor die bus
# Afrikaans (Predicted): n netwerk gebruik vaste vlotte met aggressiewe interne en swak sdhc en n skuins geleier ms om enige ander diepte te rek <EOS>
#
# English: each of the pes want to transfer data as follows
# Afrikaans (True): elk van die ves wil data as volg stuur
# Afrikaans (Predicted): van plan soos die foto soos volg soos volg <EOS>
#
# English: pe to pe bytes every ms
# Afrikaans (True): ve na ve grepe elke ms
# Afrikaans (Predicted): elke eksperimentele tydperk is dit m dood <EOS>
#
# English: pe to pe bytes every ms
# Afrikaans (True): ve na ve grepe elke ms
# Afrikaans (Predicted): elke eksperimentele tydperk is dit m dood <EOS>
#
# English: pe to pe bytes every ms
# Afrikaans (True): ve na ve grepe elke ms
# Afrikaans (Predicted): elke eksperimentele tydperk is dit m dood <EOS>
#
# English: pe to pe bytes every ms
# Afrikaans (True): ve na ve grepe elke ms
# Afrikaans (Predicted): elke eksperimentele tydperk is dit m dood <EOS>
#
# English: describe the physical layer of an ic network
# Afrikaans (True): beskryf die fisiese laag van die ic netwerk
# Afrikaans (Predicted): vorm fisiese fisiese van n netwerk <EOS>
#
# English: describe how the arbitration method used by can works
# Afrikaans (True): beskryf hoe die arbitrasie metode werk wat deur can gebruik word
# Afrikaans (Predicted): hoe die leeu metode gebruik kan word deur werk kan verkry word <EOS>
#
# English: draw the complete the logic cell circuit within the fpga which will implement the logical function seen below
# Afrikaans (True): teken die volledige logiese sel baan binne die fpga wat die onderstaande logiese funksie implenteer
# Afrikaans (Predicted): teken die volledige sel van die saak sal die logiese funksie onder insluit <EOS>
#
# English: the fpga makes use of lookup tables
# Afrikaans (True): die fpga maak gebruik van opsoektabelle
# Afrikaans (Predicted): gebruik van proteene <EOS>
#
# English: the logical function reacts on rising edge of a system clock
# Afrikaans (True): die logiese funksie reageer op die opgaande sein van die stelsel klok
# Afrikaans (Predicted): die logiese funksie reageer op die spoed van n stelsel wat verwyder word <EOS>
#
# English: explain what the term textitsoftcore processor means
# Afrikaans (True): verduidelik die betekenis van die term textitsoftcore processor
# Afrikaans (Predicted): verduidelik dui die term kolitis beteken <EOS>
#
# English: what is meant when a fpga is described as being sram based
# Afrikaans (True): wat word bedoel as n fpga beskryf word as sram gebaseerd
# Afrikaans (Predicted): wat bedoel is wanneer n item beskryf word as wat gebaseer word word volgens die boeke gebaseer word gebaseer word op grond wat gebaseer word word <EOS>
#
# English: list the four design tools used for fpga designs and what they are used for
# Afrikaans (True): lys die vier ontwerpstappe wat gebruik word in fpga ontwerpe dui ook aan wat elk doen
# Afrikaans (Predicted): die vier toerusting gereedskap wat gebruik word vir ontwerpe en wat hulle gebruik word vir gebruik vir gebruik <EOS>
#
# English: you are asked to integrate a block of vhdl code within your design
# Afrikaans (True): jy word gevra om die onderstaande blok vhdl te integreer in jou ontwerp
# Afrikaans (Predicted): dit word toegelaat om n funksie van jou binne jou beheer te verlig nie <EOS>
#
# English: a raspberrypi rp and beaglebone bb is connected to a computer pc with the laboratory the same method that was used in the practical
# Afrikaans (True): n raspberrypi rp en beaglebone bb is verbind aan n rekenaar pc in die labratorium dieselfde metode wat gebruik was in die praktikas
# Afrikaans (Predicted): n requiemmis en chevrolet is gekoppel aan n rekenaar gekoppel met dieselfde tekstuur wat dieselfde metode gebruik word in die praktiese gebruik <EOS>
#
# English: draw the timing diagram for a write operation of a cpu to a memory module on a shared synchronous bus
# Afrikaans (True): teken die tyddiagram van n skryf operasie van n sve na n geheue module op n gedeelde sinkrone bus
# Afrikaans (Predicted): teken die projek vir n erge stel n stel van die geheue vann rol wat op n gemeenskaplike taktiese bus chopra <EOS>
#
# English: draw a uml sequence diagram that shows a fourcycle handshake on a synchronous bus between a bus master and a device
# Afrikaans (True): skets n uml sekwensie diagram wat die viersiklus handskud op n sinkrone bus tussen bus meester en apparaat wys
# Afrikaans (Predicted): trek n reeks wat toon n algemene aanlyn op n gebo bus tussen n speenhulse se kant en n toestel <EOS>
#
# English: describe what is the function of a bridge in a cpu bus
# Afrikaans (True): beskryf die funksie van n brug op n sve bus
# Afrikaans (Predicted): wat as die basis van n brug in n laekostediensterminaal is in n robuuste <EOS>
#
# English: in terms of a cpu describe the difference between latency and throughput
# Afrikaans (True): in terme van n sve beskryf die verskil tussen vertraging en deursetspoed
# Afrikaans (Predicted): beskryf van die verskil tussen en die tipiese koei <EOS>
#
# English: what is the content of the cache memory if the following combination of memory locations are requested using twoway setassociative cache with two sets
# Afrikaans (True): wat is die inhoud van die kasgeheue indien die volgende kombinasies van geheue posisies aangevra word daar word n tweerigting textitsetassociative kasgeheue met twee stelle gebruik
# Afrikaans (Predicted): wat is die inhoud van die onthou indien die volgende lesers van geheue oorgedra word met behulp van twee veranderlike <EOS>
#
# English: use the leastrecently used replacement policy
# Afrikaans (True): gebruik die minste onlangse vervangings reel
# Afrikaans (Predicted): gebruik die gebruik van die beleid van die gebruik van die term <EOS>
#
# English: tabulate your answer
# Afrikaans (True): tabuleer jou antwoord
# Afrikaans (Predicted): jou antwoord antwoord op <EOS>
#
# English: describe the difference between writethrough and writeback scheme when information is written to the cachemain memory
# Afrikaans (True): beskryf die verskil tussen skryfdeur en skryfterug skemas met inligting wat geskryf word na die kasgeheuehoof geheue
# Afrikaans (Predicted): die verskil tussen en as die hoeveelheid wat waargeneem word aan die hand gekoppel aan die gang word geskryf aan die gang <EOS>
#
# English: the computer system is replaced with a modern processor with a level cache system
# Afrikaans (True): die rekenaarstelsel is vervang met n moderne verwerker met n vlak kasgeheue stelsel
# Afrikaans (Predicted): die rekenaar stelsel is met n moderne q met n vlak van n vlak van die vlak <EOS>
#
# English: what is the average access time assuming the memory access times are ttextl text ns ttextl text ns ttextl text ns and ttextmain text ns and the hit ratio of the caches are htextl htextl and htextl
# Afrikaans (True): wat is die gemiddelde toegangstyd indien daar aanvaar word dat ttextl text ns ttextl text ns ttextl text ns en ttextmain text ns en dat die sukses verhoudings van die kasgeheue htextl htextl en htextl is
# Afrikaans (Predicted): wat die gemiddelde toegang is het die tyd toegang tot die memory behoort s n teks van n teks artikel en teks <EOS>
#
# English: under what circumstances would the efmzgf be preferred above the efmzgf
# Afrikaans (True): onder watter omstandighede sal die efmzgf verkies word bo die efmzgf
# Afrikaans (Predicted): soos wat die s sou die hierbo bo die s sou wees <EOS>
#
# English: under what circumstances would the efmzgf be preferred above the efmzgf
# Afrikaans (True): onder watter omstandighede sal die efmzgf verkies word bo die efmzgf
# Afrikaans (Predicted): soos wat die s sou die hierbo bo die s sou wees <EOS>
#
# English: name three factors which influencedetermine power consumption in cmos microprocessors
# Afrikaans (True): noem drie faktore wat kragverbruik beivloedbepaal in cmos mikroverwerkers
# Afrikaans (Predicted): drie faktore wat in die kus in gene aangetref word <EOS>
#
# English: provide two userlevel examples one for static and one for dynamic power management
# Afrikaans (True): gee twee gebruikervlak voorbeelde een vir n staties en n ander vir dinamiese kragbestuur
# Afrikaans (Predicted): gelykstroom twee voorbeelde hiervan vir statiese en een van chromatiese krag <EOS>
#
# English: what would be a likely reason why returning to mode em from em takes so long compared to the other energy mode
# Afrikaans (True): wat is die waarskynlike rede waarom die tyd wat nodig is om terug te gaan na em vanaf em soveel langer is as die ander modusse
# Afrikaans (Predicted): wat n mens is ingebring om terug te speel van em mark om n groter uit te beeld <EOS>
#
# English: three devices are attached to a microprocessor
# Afrikaans (True): drie toestelle is aan n mikroverwerker gekoppel
# Afrikaans (Predicted): hou verbonde aan n deelnemer wat besig is n kort <EOS>
#
# English: device has highest priority and device has lowest priority
# Afrikaans (True): toestel het die hoogste prioriteit en toestel het die laagste prioriteit
# Afrikaans (Predicted): hou n hoogste prioriteit en toestel het die laagste prioriteit <EOS>
#
# English: each devices interrupt handler takes time units to execute
# Afrikaans (True): elke toestel se onderbrekingsroetine neem tydeenhede om uit te voer
# Afrikaans (Predicted): elektriese lampe neem na vlugte in hekke <EOS>
#
# English: show what interrupt handler if any is executing at each time unit given the sequence of device interrupts displayed below
# Afrikaans (True): wys watter onderbrekingsroetine indien enige is besig om uit te voer by elke tydeenheid gegee die sekwensie van onderbrekings soos hieronder aangedui
# Afrikaans (Predicted): toon wat as enige keer op dieselfde tyd is wanneer die volgorde van die motief hieronder beweeg <EOS>
#
# English: assume interrupts can be interrupted
# Afrikaans (True): neem aan onderbrekings kan onderbreek word
# Afrikaans (Predicted): kan daar bestaan word nie <EOS>
#
# English: describe under what circumstances an embedded system would prefer using busywait io or interruptdriven io
# Afrikaans (True): beskryf onder watter omstandighede n toegewyde stelsel verkies om besigwag iu of onderbreking gedrewe iu te gebruik
# Afrikaans (Predicted): as wat so n bekende stelsel sou gebruik maak van die karakter of papier <EOS>
#
# English: the functional block shows a dma module
# Afrikaans (True): die funksionele blokdiagram toon n dma module
# Afrikaans (Predicted): die funksionele blok het dwergbokke met die voorste moment n voorste brandpunt <EOS>
#
# English: describe the events that takes place around a dma transfer
# Afrikaans (True): beskryf die gebeure wat plaasvind tydens n dma oordrag
# Afrikaans (Predicted): dui die gebeure dat ongeveer n oordrag van ongeveer plek in n mens plaasvind <EOS>
#
# English: what is the function of a watchdog timer
# Afrikaans (True): wat is die funksie van n textitwatchdog teller
# Afrikaans (Predicted): wat is die funksie van n samehangende gedokumenteer <EOS>
#
# English: what type of embedded network will be suitable to create this type of system
# Afrikaans (True): watter tipe toegewyde netwerk sal geskik wees om hierdie stelsel te skep
# Afrikaans (Predicted): wat dit gebruik word om iets te maak klink dit kan gebruik word om menslike materiaal te skep <EOS>
#
# English: give a reason for your answer
# Afrikaans (True): gee n rede vir jou antwoord
# Afrikaans (Predicted): gee n rede vir jou antwoord <EOS>
#
# English: show with calculations to what percentage of the maximum capacity the network is being used
# Afrikaans (True): toon deur berekeninge tot watter persentasie van maksimum kapasiteit die netwerk benut word
# Afrikaans (Predicted): met die mens se betekenis wat aan die persentasie kapasiteit kan word word die netwerk gebruik <EOS>
#
# English: assume that only pes and pes data can be divided in smaller packets
# Afrikaans (True): aanvaar dat slegs ve en ve se data in kleiner pakkies opgedeel mag word
# Afrikaans (Predicted): aanvaar dat die mate van die verwydering van n verlies van die koop in kleiner en koop kan word <EOS>
#
# English: show the sequence of transactions and packet sizes on the bus over a timeslot of ms so that all pes can make their deadlines
# Afrikaans (True): toon die volgorde van transaksies en pakkie groottes op die bus oor ms tydgleuf sodat alle ves hulle spertye haal
# Afrikaans (Predicted): wys die volgorde van die sosiale en groottes op die selfverslag oor n van n mens kan almal hulle vinniger raak maak hulle omring <EOS>
#
# English: you have decided to construct a vhdl testbench for the vhdl component
# Afrikaans (True): jy het besluit om n vhdl toetsbank te skep vir die vhdl komponent
# Afrikaans (Predicted): het besluit om n lid van die lewe te sien nie <EOS>
#
# English: write the vhdl code for the two missing processes
# Afrikaans (True): skryf die vhdl kode vir die twee ontbrekende prosesse
# Afrikaans (Predicted): vir die twee stap prosesse <EOS>
#
# English: the process textttclock must generate a mhz clock and the textttstimilus process must trigger the reset line after ns from the start of the simulation assume the enable line is high
# Afrikaans (True): die proses textttclock moet n mhz klok genereer en die textttstimilus proses moet die reset lyn stimuleer na ns vandat die simulasie begin het
# Afrikaans (Predicted): die proses moet n plan word om die reaksie te meet moet die lyn n bykomende wees van n ondersoek van die loop van die loop af af te neem
#
# English: the reset line must be high for ns before returning to
# Afrikaans (True): die reset lyn moet hoog wees vir ns voordat weer terug gaan na
# Afrikaans (Predicted): moet n groter weergawe voor terwyl dit in terug terug te keer dat dit na die begin om te word <EOS>
#
# English: the first few lines of the testbench are given below
# Afrikaans (True): die eerste paar lyne van die toetsbank word gegee hieronder
# Afrikaans (Predicted): funksioneer van hieronder word volgens gerangskik volgens <EOS>
#
# English: the output given below is seen from the bb
# Afrikaans (True): die onderstaande uitree word gesien met die gebruik van n bb
# Afrikaans (Predicted): wat die van die mis gesien word is die natuurlik van enige natuurlik gesien <EOS>
#
# English: which file contains assembly instructions
# Afrikaans (True): watter leer bevat saamsteltaal
# Afrikaans (Predicted): wat die musiek vereis om die mens se smaak te maak dat instruksies die musiek vereis dat instruksies die musiek vereis dat instruksies die musiek vereis het <EOS>
#
# English: for the network between all the nodes to work the command below is required
# Afrikaans (True): die onderstaande opdrag is nodig om n suksesvolle netwerk te skep tussen al die nodusse
# Afrikaans (Predicted): volgens die netwerk tussen alle die werk wat die opdrag onder die nodige nodig is wat nodig is nodig <EOS>
#
# English: on which device must this command be executed and what does this command do
# Afrikaans (True): op watter toestel moet hierdie opdrag uitgevoer word en wat is die doel van hierdie opdrag
# Afrikaans (Predicted): wat hierdie veld sal wees en wat hierdie bevel versamel moet word dat dit maklik terug sal word <EOS>
#
# English: describe three ways you can use to measure the execution time of code segments on an embedded computer like a rp or a bb
# Afrikaans (True): beskryf drie maniere hoe jy die uitvoer tyd van n blok kode kan meet in n toegewyde stelsel soortgelyk aan n rp en n bb
# Afrikaans (Predicted): beskryf drie maniere moontlik kan gebruik om die geskenk van jou veranderlike op n sogenaamde rekenaar te voeg soos n resistor <EOS>
#
# English: it was seen during a practical test that the bb completed the program primesc faster than the rp but the rp completed the program cardc faster
# Afrikaans (True): tydens die uitvoering van n prakties was dit opgemerk dat die bb die program primesc vinniger uitvoer as die rp maar dat die rp die program cardc vinniger voltooi
# Afrikaans (Predicted): dit was voorheen tydens n praktiese toets wat die sak benvloed het as die vleis maar die vleis het ook geen invloed op die brand <EOS>
#
# English: supply a reason for this observation
# Afrikaans (True): gee n rede vir hierdie observasie
# Afrikaans (Predicted): n rede hiervoor hierdie bladmusiek <EOS>
#
# English: additional flags are added to the compile command of the bb of the cardc program
# Afrikaans (True): ekstra vlaggies is bygevoeg tot die kompileerder opdrag van die bb van die cardc program
# Afrikaans (Predicted): mediese geslag word by die vorming van die groente van die verhaal van die groep van die verhaal van die verhaal aangebied <EOS>
#
# English: what extra information is supplied to the compiler and what effect will it have on the execution time of the program
# Afrikaans (True): watter ekstra inligting word verskaf aan die kompileerder en watter effek sal dit he op die uitvoertyd van die program
# Afrikaans (Predicted): ekstra ekstra inligting word op die speletjie en what moet dit op die teregstelling toegepas word <EOS>
#
# English: shortly describe what a cross compiler is
# Afrikaans (True): beskryf kortliks wat n kruisvertaler is
# Afrikaans (Predicted): beskryf what n houer is is dood <EOS>
#
# English: is a crosscompiler used in the creation of the application for the bb in the practical
# Afrikaans (True): is n kruisvertaler gebruik in die skep van die program vir die bb van die prakties
# Afrikaans (Predicted): in die skepping van die toepassing vir die kromme in die praktiese situasie <EOS>
#
# English: in terms of a cpu describe the difference between latency and throughput
# Afrikaans (True): in terme van n sve beskryf die verskil tussen vertraging en deursetspoed
# Afrikaans (Predicted): beskryf van die verskil tussen en die tipiese koei <EOS>
#
# English: what are the stages of the instruction pipeline of a arm processor
# Afrikaans (True): wat is die fases van die instruksiepyplyn van n arm verwerker
# Afrikaans (Predicted): wat die stadiums van die onderrig se antwoorde toon n erge uitvoering <EOS>
#
# English: given a device connected to the cpu as shown in the diagram below
# Afrikaans (True): gegee n toestel verbind aan n sve soos die onderstaande diagram
# Afrikaans (Predicted): n toestel wat aan die gewoonte in die diagram onder gesien word soos hieronder bespreek <EOS>
#
# English: list and describe each of the three types of cache misses that can occur in an embedded system
# Afrikaans (True): lys en beskryf elkeen van die drie tipes kasgeheue misse wat kan voorkom in n toegewyde stelsel
# Afrikaans (Predicted): elkeen beskryf beskryf van die drie soorte kombinasies wat in n aflewering stelsel kan kan word <EOS>
#
# English: the following code is within the program memory of a arm processor with an empty single level cache the program counter starts at address x
# Afrikaans (True): die volgende kode is binne the program geheue van n arm verwerker met n enkel vlak kasgeheue die programteller begin by die adres x
# Afrikaans (Predicted): die volgende is dan binne die soek van n arm verwerker met n kort enkele vermons die program met die x beheer <EOS>
#
# English: given the functional block diagram of the msppr microcontroller
# Afrikaans (True): gegee die funksionele blok diagram van die msppr mikroverwerker
# Afrikaans (Predicted): diagram natuurlik is die vorm van die prioriteit <EOS>
#
# English: a master msppr is connected to two slaves picffamily on an ic bus
# Afrikaans (True): n meester msppr is verbind aan twee slawe picffamilie op n ic bus
# Afrikaans (Predicted): n meester is aan twee kant geheg is n persoon se stelling op n bus <EOS>
#
# English: explain what it means ito fpga architecture when a fpga is described as being flash based how does this influence the programming of the fpga
# Afrikaans (True): verduidelik wat word bedoel itv fpga argitektuur asn fpga beskryf word as flash gebaseerd hoe beinvloed dit die programmering van die fpga
# Afrikaans (Predicted): beskryf dit beteken dat daar per ongeluk per as beskryf word beskryf dit asof die mens die verhaal van die musiek versamel <EOS>
#
# English: describe shortly the code structure of a vhdl testbench
# Afrikaans (True): beskryf kortliks die kode struktuur van n vhdl toetsbank
# Afrikaans (Predicted): uit die kode van n advokaat <EOS>
#
# English: you are asked to optimise part of an asic system
# Afrikaans (True): u word gevra om deel van n asic stelsel te optimeer
# Afrikaans (Predicted): gevra word in die verhouding van n stelsel uitgebeeld <EOS>
#
# English: the algorithm that is currently implemented in software calculates the least common multiple lcm of two bit numbers and gives a bit result
# Afrikaans (True): die algoritme wat tans in sagteware geimplementeer is bereken die kleinste gemene veelvoud kgv van twee bit getalle en gee n bit antwoord
# Afrikaans (Predicted): die wind wat tans gemplementeer word word die wind baie dieselfde hoeveelheid van twee toonlere getalle en skep n bietjie resultaat resultaat <EOS>
#
# English: you decide to split the design into a datapath and state machine controller
# Afrikaans (True): u besluit om die ontwerp in n datapad en toestandsmasjien beheerder op te deel
# Afrikaans (Predicted): jy probeer om die ontwerp in n sosiale toestand te kom en n verhoogde toestand te bereik <EOS>
#
# English: textbflcm example
# Afrikaans (True): textbfkgv voorbeeld
# Afrikaans (Predicted): SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS
#
# English: base numbers
# Afrikaans (True): basis getalle
# Afrikaans (Predicted): basis <EOS>
#
# English: iteratively add the matching base number to the smallest sum until the two sum values are equal
# Afrikaans (True): tel iteratief die ooreenstemmende basis getal by die kleinste som totdat twee som waardes gelyk is
# Afrikaans (Predicted): die kleur se syfer tot die kleinste som totdat die twee som van die impak is gelyk <EOS>
#
# English: a raspberrypi rp and beaglebone bb is connected to a computer pc with the laboratory the same method that was used in the practical
# Afrikaans (True): n raspberrypi rp en beaglebone bb is verbind aan n rekenaar pc in die labratorium dieselfde metode wat gebruik was in die praktikas
# Afrikaans (Predicted): n requiemmis en chevrolet is gekoppel aan n rekenaar gekoppel met dieselfde tekstuur wat dieselfde metode gebruik word in die praktiese gebruik <EOS>
#
# English: what is the difference between an interrupt exception and trap within a processor
# Afrikaans (True): wat is die verskil tussen n onderbreking uitsondering en n textittrap in n verwerker
# Afrikaans (Predicted): dit is die verskil tussen n deeeuse en storm binne n skuins in n plat <EOS>
#
# English: what is the interrupt called which has the highest priority within a cpu
# Afrikaans (True): wat is the onderbreking met die hoogste prioriteit binne n sve
# Afrikaans (Predicted): wat die sogenaamde liggaam in n teenwoordige prioriteit het het sy n verloop van n groter prioriteit in <EOS>
#
# English: describe the content of the interrupt vector table
# Afrikaans (True): beskryf die inhoud van die onderbreking vektor tabel
# Afrikaans (Predicted): ingevolge die vektor van die vektor tafel <EOS>
#
# English: describe the complete process for a cpu handling an interrupt generated by the device as shown in the diagram using a sequence diagram
# Afrikaans (True): beskryf die hele proses hoe n sve n onderbreking deur n toestel soos gewys word in die diagram hanteer gebruik n sekwensie diagram
# Afrikaans (Predicted): beskryf die volledige proses vir n hantering van n toestel deur n toestel as wat in die diagram gebruik word <EOS>
#
# English: what is the equivalent ccode of this collection of assembly instructions
# Afrikaans (True): wat is die ekwivalente ckode van die saamstelinstruksies
# Afrikaans (Predicted): volgens hierdie standpunt van hierdie versameling van afrikaans en raak dus as uganda <EOS>
#
# English: what is the content of the directmapped instructioncache with eight lines configuration
# Afrikaans (True): wat is die inhoud van die direkteverwysde instruksie kasgeheue met agt rye
# Afrikaans (Predicted): wat die inhoud van is met sterk lyne <EOS>
#
# English: assume each line holds one arm instruction
# Afrikaans (True): aanvaar dat elke ry slegs een arm instruksie hou
# Afrikaans (Predicted): elke elke hou op die stygende probleme in hierdie geval weer n slegte wisselwerking in hierdie poging <EOS>
#
# English: tabulate your answer with table headings block tag and data
# Afrikaans (True): tabuleer jou antwoord met tabel opskrifte block tag en data
# Afrikaans (Predicted): jou onverwagte antwoord met oproep van sjabloonwebaanhaling of ander is op die oorspronklike aantal produk en data oor die web van light of meer algemeen met n ander gedeelte van
#
# English: what is the total memory access time for the full execution of the code given that ttextcache text ns and ttextmain text ns
# Afrikaans (True): wat is die totale geheue toegang tyd vir die volledige uitvoer van die kode gegee dat ttextcache text ns en ttextmain text ns
# Afrikaans (Predicted): wat die totale tegniek gaan vir die volledige rol van die kode wat gebruik word en die aktrise het n mate van vliegtuigbewegings <EOS>
#
# English: what is the average memory access time for the full execution of the code given that ttextcache text ns and ttextmain text ns
# Afrikaans (True): wat is die gemiddelde geheue toegang tyd vir die volledige uitvoer van die kode gegee dat ttextcache text ns en ttextmain text ns
# Afrikaans (Predicted): wat die gemiddelde toets het vir die volledige rels van die kode gegee dat teks n resensie en aanbieding n mate gebruik word <EOS>
#
# English: you are asked to optimise this section of code using loopunrolling
# Afrikaans (True): jy word gevra om hierdie gedeelte kode te optimeer deur gebruik te maak van textitloopunrolling
# Afrikaans (Predicted): word toegelaat om hierdie gedeelte te bewerkstellig met behulp van die volgende met behulp van die volgende deur die volgende te gebruik <EOS>
#
# English: what does this technique imply
# Afrikaans (True): wat behels hierdie tegniek
# Afrikaans (Predicted): ondersoek hierdie tegniek impliseer <EOS>
#
# English: will it improve the execution speed
# Afrikaans (True): sal hierdie tegniek die uitvoertyd verbeter
# Afrikaans (Predicted): dit maak die organisasie die wet se stelsel om die teregstelling te verbeter <EOS>
#
# English: give a reason for your answer
# Afrikaans (True): gee n rede vir jou antwoord
# Afrikaans (Predicted): gee n rede vir jou antwoord <EOS>
#
# English: what is the function of jtag
# Afrikaans (True): wat is die funksie van jtag
# Afrikaans (Predicted): die funksie van <EOS>
#
# English: what is the most likely architecture for this family of processors
# Afrikaans (True): wat is die waarskynlike argitektuur van hierdie familie van verwekers
# Afrikaans (Predicted): wat waarskynlik die grootste argitektuur is vir hierdie tale van frank <EOS>
#
# English: give a reason for your answer
# Afrikaans (True): gee n rede vir jou antwoord
# Afrikaans (Predicted): gee n rede vir jou antwoord <EOS>
#
# English: what is the function of the dma module
# Afrikaans (True): wat is die funksie van die dma module
# Afrikaans (Predicted): die funksie van die voorste orkes <EOS>
#
# English: the bit adc peripheral is used to sample an audio system
# Afrikaans (True): die bit adc module word gebruik om n audio stelsel te monster
# Afrikaans (Predicted): die woord paneel van die woord word gebruik om n klank stelsel te beskryf <EOS>
#
# English: the bus can only transport a single byte each clock cycle thus the bit measurement is seen as a bit number with the msb set as zeros
# Afrikaans (True): die bus kan slegs n enkele greep elke kloksiklus stuur dus word die bit meting gesien as n bit nommer met die msb gestel as nul
# Afrikaans (Predicted): die bus kan slegs n plat verbind elk elke geval word dus die bis meting word as n bietjie gemeng met die ooreenstemmende soos aspartaam <EOS>
#
# English: calculate the total bytessec required for an audio signal of bitssample per channel eight channels each sampled at khz
# Afrikaans (True): bereken die totale grepesek wat benodig word om die klanksein van bitsmeting per kanaal agt kanale elk gemonster teen khz
# Afrikaans (Predicted): indien die totale vliegtuig vereis vir n klank van per silinder agt elke keer op deutsche <EOS>
#
# English: assuming that nonburst mode transfers are used and d o also calculate the minimum bus clock speed required to handle the data
# Afrikaans (True): aanvaar dat geen textitburst modes transaksies gebruik word nie en d o bereken ook die minimum bus klokspoed wat benodig word om hierdie data te hanteer
# Afrikaans (Predicted): as sulks word die s oorgedra en d o ook gebruik die opstel van die lugwe wat vereis om die data te hanteer <EOS>
#
# English: the microcontroller only has one bus that connects all the peripherals to the cpu
# Afrikaans (True): hierdie mikroverwerker het slegs een bus wat al die randaparatuur verbind aan die sve
# Afrikaans (Predicted): daar is n man wat alle die vertrek aan die gang verbind na die <EOS>
#
# English: draw a block diagram of the bus topology if an advanced arm amba bus system is used
# Afrikaans (True): teken n blokdiagram van die bus topologie indien n gevorderde arm amba busstelsel gebruik work
# Afrikaans (Predicted): teken n blokdiagram van die bepaling as n gevorderde arm stelsel word gebruik <EOS>
#
# English: show the busses their connections and some typical components connected to them
# Afrikaans (True): wys die busse hul konneksies en n paar tipiese komponenterandaparatuur wat verbind aan die busse
# Afrikaans (Predicted): die doel van en n tipiese komponente wat die mens se hoogte is aan hulle begin hou met hulle <EOS>
#
# English: indicate the names of the components clearly
# Afrikaans (True): dui duidelik die name van die komponente aan
# Afrikaans (Predicted): of die komponente duidelik uit sowel komponente <EOS>
#
# English: the master wants to write the byte xaa to slave bit address is xa
# Afrikaans (True): die meester wil die greep xaa na slaaf bit adres is xa stuur
# Afrikaans (Predicted): daar is die sein om die beweging te verlaat wat werklik genoem is is egter lelik <EOS>
#
# English: draw the timing diagram of the signals which should appear on the scl and sdl lines when using an oscilloscope
# Afrikaans (True): teken die tyddiagram van die seine wat n ossiliskoop sal meet van die scl en sdl lyne
# Afrikaans (Predicted): die projek diagram van die seine wat op die fokus op die foto gebruik word wanneer dit gevorm word <EOS>
#
# English: the master sent a write request xb to slave bit address x but did not receive an ack
# Afrikaans (True): die meester stuur n skryf transaksie xb na slaaf bit adres x maar het nie n ack ontvang nie
# Afrikaans (Predicted): die meester stuur n voorstel om die oortollige adres te span en ek het nie n span gekies nie maar het niks nie <EOS>
#
# English: give two possible reasons why the slave did not respond
# Afrikaans (True): gee twee moontlike redes hoekom die slaaf nie geantwoord het nie
# Afrikaans (Predicted): gee twee moontlike redes die oorsprong het nie op die estetiese geval nie op die laat sak nie <EOS>
#
# English: what multiprocessor architecture is the system above
# Afrikaans (True): watter multiverwerker argitektuur is die bostaande stelsel
# Afrikaans (Predicted): wat die stelsel bo die stelsel is <EOS>
#
# English: provide a reason for your answer
# Afrikaans (True): gee n rede vir jou antwoord
# Afrikaans (Predicted): jy maak jou jou antwoord op jou antwoord <EOS>
#
# English: the designer of this system wants to change the current bus network from ic to can
# Afrikaans (True): die ontwerper van hierdie stelsel wil die huidige bus verander vanaf ic na can
# Afrikaans (Predicted): die nes van hierdie stelsel wil verander die huidige bus van tot kan kan tot <EOS>
#
# English: describe the changes required
# Afrikaans (True): beskryf die nodige veranderinge
# Afrikaans (Predicted): sal die veranderinge vereis <EOS>
#
# English: what are the prerequisites andor changes that are required if this system is implemented using spi
# Afrikaans (True): wat is die voorvereistes enof veranderinge wat nodig is indien die stelsel spi wil implementeer
# Afrikaans (Predicted): wat die enof veranderinge wat benodig word indien dit n stelsel genoem word deur gebruik te word <EOS>
#
# English: which aspect of an asic device makes it more ideal than a fpga in this scenario
# Afrikaans (True): watter aspek van n asic toestel maak dit meer geskik as n fpga in hierdie geval
# Afrikaans (Predicted): wat stukke n karakter maak maak dit meer as n effens soos hierdie gedrag <EOS>
#
# English: by using basic ipcores functional blocks underlinesketch the datapath part of your design
# Afrikaans (True): deur gebruik te maak van basiese iekerns funksionele blokke underlineskets die datapad gedeelte van u ontwerp
# Afrikaans (Predicted): deur middel van die ontwerp van die ontwerp van die ontwerp van die ontwerp van die ontwerp <EOS>
#
# English: the output below is seen from the bb
# Afrikaans (True): die onderstaande uitree word gesien met die gebruik van n bb
# Afrikaans (Predicted): soos die kom van die mis gesien word gesien as die mis gesien <EOS>
#
# English: supply the commands required to compile and run the mainc program with optimisation level
# Afrikaans (True): gee die opdragte wat nodig is om die mainc program te kompileer met optimeringsvlak en die program uit te voer
# Afrikaans (Predicted): die stuur van vereis met die industrie en loop die personeel met gelyke <EOS>
#
# English: for the network between all the nodes to work the command below is required
# Afrikaans (True): die onderstaande opdrag is nodig om n suksesvolle netwerk te skep tussen al die nodusse
# Afrikaans (Predicted): volgens die netwerk tussen alle die werk wat die opdrag onder die nodige nodig is wat nodig is nodig <EOS>
#
# English: on which device must this command be executed and what does this command do
# Afrikaans (True): op watter toestel moet hierdie opdrag uitgevoer word en wat doen hierdie opdrag
# Afrikaans (Predicted): wat hierdie veld sal wees en wat hierdie bevel versamel moet word dat dit maklik terug sal word <EOS>
#
# English: describe the network layer of the osi model as it is implemented on the network used for the rp bb and pc
# Afrikaans (True): beskryf die netwerk vlak van die osi model soos wat dit geimplementeer word vir die rp bb en pc
# Afrikaans (Predicted): as netwerk netwerk van die model as dit word op die netwerk van die netwerk staan gebruik en die woord word bv vesel genoem <EOS>
#
# English: you have a choice between the rp and bb
# Afrikaans (True): jy het die keuse tussen die rp en bb
# Afrikaans (Predicted): daar is n keuse tussen die pynlike en groente <EOS>
#
# English: for each of the applications below indicate what will be your choice in each case and give a motivation
# Afrikaans (True): vir elk van die onderstaande toepassings wat sal jou keuse wees in elk van die gevalle en verskaf n rede
# Afrikaans (Predicted): vir elke toepassings van dui dit wat aandui sal wees vir elke gebeure en gee n motivering <EOS>
#
# English: you only have one of each of these devices
# Afrikaans (True): jy het slegs een van elk van die toestelle
# Afrikaans (Predicted): daar bestaan uit hierdie toestelle hierdie vorms van hierdie toestelle <EOS>
#
# English: embedded computing
# Afrikaans (True): toegewyde verwerking
# Afrikaans (Predicted): wat kandinsky betref <EOS>
#
# English: uml description
# Afrikaans (True): uml beskrywing
# Afrikaans (Predicted): <EOS>
#
# English: system design
# Afrikaans (True): stelsel ontwerp
# Afrikaans (Predicted): melodie <EOS>
#
# English: program design and analysis
# Afrikaans (True): program ontwerp en analise
# Afrikaans (Predicted): en ontleding van ontleding <EOS>
#
# English: processes and operating systems
# Afrikaans (True): prosesse en bedryfstelsels
# Afrikaans (Predicted): prosesse en wat opnames behels <EOS>
#
# English: instruction sets
# Afrikaans (True): instruksiestelle
# Afrikaans (Predicted): dramatiese probleme <EOS>
#
# English: assume the bottomup design view is followed
# Afrikaans (True): aanvaar die ondernabo ontwerp proses is gevolg
# Afrikaans (Predicted): kom die algemene ontwerp op die punt gevolg word gevolg van die tyd gevolg gevolg gevolg <EOS>
#
# English: sort the major levels of abstraction of the embedded system design process in the right order
# Afrikaans (True): sorteer die hoof vlakke van abstraksie van n toegewydestelsel ontwerpproses in die regte volgorde
# Afrikaans (Predicted): die kleiner vlakke van die oorsprong van die oorsprong van die steel stelsel in die regte volgorde <EOS>
#
# English: system integration
# Afrikaans (True): stelsel integrasie
# Afrikaans (Predicted): teiken <EOS>
#
# English: requirements
# Afrikaans (True): vereistes
# Afrikaans (Predicted): die vereistes <EOS>
#
# English: component
# Afrikaans (True): komponent
# Afrikaans (Predicted): SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS
#
# English: architecture
# Afrikaans (True): argitektuur
# Afrikaans (Predicted): argitektuur <EOS>
#
# English: specification
# Afrikaans (True): spesifikasies
# Afrikaans (Predicted): wisselstroom <EOS>
#
# English: at which stage of the design process would we choose the communication protocol between subsystems
# Afrikaans (True): by watter stap van die ontwerpsproses word die kommunikasiekanaal tussen substelsels gekies
# Afrikaans (Predicted): van die ontwerp sou egter die deiktiese struktuur tussen die kommunikasie sou tussen oorgedra sou word <EOS>
#
# English: motivate your answer
# Afrikaans (True): motiveer jou antwoord
# Afrikaans (Predicted): jou antwoord <EOS>
#
# English: describe the meaning if a system is described as a cyberphysical system
# Afrikaans (True): wat is die betekenis as n stelsel beskryf word as n kuberfisiese stelsel
# Afrikaans (Predicted): wanneer die betekenis as n stelsel beskryf word as n stelsel beskryf as n stelsel <EOS>
#
# English: extract four requirements of a standard cansat mission by using the description below
# Afrikaans (True): ontrek vier vereistes van n standaard cansat missie deur gebruik te maak van die onderstaande beskrywing
# Afrikaans (Predicted): uit vier standaard foto deur n beskrywing van die beskrywing onder te wend onder die beskrywing onder <EOS>
#
# English: the cansat will be built by the final year cs class
# Afrikaans (True): die cansat word gebou deur die finale jaar rs klas
# Afrikaans (Predicted): gebou is deur die finale jaar lange klas <EOS>
#
# English: the cansat is launched from a rocket and its mission time must be maximised
# Afrikaans (True): die cansat word gelanseer deur n vuurpyl en die missie moet so lank duur as moontlik
# Afrikaans (Predicted): dit is van n saak en sy missie moet dit moet wees <EOS>
#
# English: a ground station will receive the necessary information to track the movement of the cansat
# Afrikaans (True): n grondstasie sal die nodige inligting ontvang om die beweging van die cansat te bepaal
# Afrikaans (Predicted): n grond sal die nodige inligting vergroot om die beweging van die gebou te maksimeer <EOS>
#
# English: the cansat will be retrieved after returning to the ground
# Afrikaans (True): die cansat sal teruggekry word nadat dit geland het
# Afrikaans (Predicted): url besoek op november om terug te verlaat by die grond te verwyder <EOS>
#
# English: what is the main aim of uml in system design
# Afrikaans (True): wat is die hoof doel van uml in stelsel ontwerp
# Afrikaans (Predicted): wat die wet is in stelsel ontwerp <EOS>
#
# English: draw a uml class diagram for the objects involved in a cruise control of a car
# Afrikaans (True): teken n uml klas diagram vir die objekte betrokke by die spoedbeheer van n voertuig
# Afrikaans (Predicted): teken n klas matras vir die aktiwiteite wat in n germaanse plek van n motor beheer is <EOS>
#
# English: the system must be able to increase and decrease the reference speed from buttons on the steering wheel
# Afrikaans (True): die stelsel moet die spoedverwysing kan verhoog en verlaag deur knoppies op die stuurwiel
# Afrikaans (Predicted): moet die stelsel in die omgewing verhoog word en verminder die verwysing van die satelliet op die blaaroppervlak op die blaaroppervlak <EOS>
#
# English: include classes for the buttons engine management system and electronic throttle control
# Afrikaans (True): sluit in klasse vir knoppies enjin bestuur stelsel en elektroniese petrol beheer
# Afrikaans (Predicted): sluit klasse vir die sagteware en elektroniese stelsel beheer beheerstelsels <EOS>
#
# English: define at least a number of important functions to describe the influence on other classes
# Afrikaans (True): definieer ten minste n paar belangrike funksies wat gebruik kan word om die ander klasse te beinvloed
# Afrikaans (Predicted): ten minste een of belangrike terreine van die publikasie van die onderwerp op ander faktore benvloed anders op ander klasse <EOS>
#
# English: refer to the class diagram below of a camera system connected to an onboard computer obc
# Afrikaans (True): verwys na die onderstaande klas diagram van n kamera stelsel wat verbind is aan n aanboordrekenaar
# Afrikaans (Predicted): verwys na die klas soos hieronder van n kamera stelsel wat aan n aandag aan n toegeskryf aan n toegeskryf aan die redakteur toegeskryf word <EOS>
#
# English: the obc always waits for an acknowledge from the camera module before continuing to the next command
# Afrikaans (True): die rekenaar wag altyd vir n antwoord van die kamera module voordat dit aanbeweeg na die volgende opdrag
# Afrikaans (Predicted): die s het n groot uit die kamera module voor hoe om die volgende bevel te verhoog <EOS>
#
# English: a new file is created on the sdcard after an image have successfully captured
# Afrikaans (True): n nuwe leer word geskep op die sdkaart nadat n beeld suksesvol geneem is
# Afrikaans (Predicted): n nuwe ler is op die foto geplaas n foto het n verkeerde suksesvol opgelewer wat gelei het <EOS>
#
# English: this file is appended after an image frame have successfully been downloaded
# Afrikaans (True): suksesvolle beeldvensters word bygevoeg aan die einde van hierdie leer
# Afrikaans (Predicted): hierdie sirkel is n n plat wat plat is opgeneem is herkenbaar ens is herkenbaar hanteer <EOS>
#
# English: use the functions defined in the classes and construct a sequence diagram of the process of capturing downloading and saving of a single image frame from the camera module to the sdcard on the obc
# Afrikaans (True): gebruik die gedefineerde funksies in hierdie klasse en skep n sekwensie diagram van die proses van die neem aflaai en stoor van n enkele venster van die beeld vanaf die kamera module tot die sdkaart op die aanboordrekenaar
# Afrikaans (Predicted): die funksies wat in die waarnemer verwys en uitvoer n sekwent gebed van die proses van die bestuurder se bestuurder en gemonteer van n kamera se uitset aan die kamera
#
# English: describe shortly the difference between the waterfall and spiral models
# Afrikaans (True): verduidelik kortliks die verskil tussen die waterval en die spiraal modelle
# Afrikaans (Predicted): beskryf die verskil tussen die v en standbeelde modelle <EOS>
#
# English: briefly describe a design review and the main reasons for performing a review
# Afrikaans (True): beskryf kortliks n ontwerpsresensie en die hoof rede hoekom dit gedoen word
# Afrikaans (Predicted): beskryf n reeks review en die hoofkarakter vir n model <EOS>
#
# English: describe what is iso and what is the advantage of implementing it
# Afrikaans (True): beskryf wat bedoel word met iso en wat is die voordeel om dit te implementeer
# Afrikaans (Predicted): wat die oorspronklike benodig word en wat die voordeel vir die ondersoek van die maak dit dit verstaan <EOS>
#
# English: describe the difference between whitebox and blackbox testing
# Afrikaans (True): beskryf die verskil tussen textitwhitebox en textitblackbox toetsing
# Afrikaans (Predicted): tussen verskil en die bevolking in soutgehalte en die bevolking tussen dro en soutgehalte in die bevolking tussen en die bevolking tussen tegnologie <EOS>
#
# English: describe the entire tool chain for developing software and flashing the program onto a microcontroller
# Afrikaans (True): beskryf die hele textittool chain vir die ontwikkeling van die sagteware en die oplaai van die program op n mikroverwerker
# Afrikaans (Predicted): die hele prioriteit vir die berging van die berging en lug die polisie op die loop van n ry op <EOS>
#
# English: describe the activity and the output of each step
# Afrikaans (True): beskryf die aksie en die uitree van elke stap
# Afrikaans (Predicted): soos in die repertoire van elke stap <EOS>
#
# English: write the singleassignment form of the block ccode below and draw the dataflow graph
# Afrikaans (True): skryf die enkeltoedeling vorm van die onderstaande blok ckode en teken die datavloei diagram
# Afrikaans (Predicted): hy vorm die reeks onder en sluit die stelsel uit en versamel <EOS>
#
# English: see the block ccode below
# Afrikaans (True): sien die onderstaande blok ckode
# Afrikaans (Predicted): onder die stutte hieronder <EOS>
#
# English: identify four methods the compiler might employ to optimize this code for faster execution
# Afrikaans (True): identifiseer vier metodes wat die samesteller moontlik mag gebruik om die kode te optimeer om vinniger uit te voer
# Afrikaans (Predicted): dit is geneig om die eksperiment te wysig vir vinniger om vinniger te verhoog <EOS>
#
# English: what is the central part of an operating system responsible for controlling access to the cpu memory and other shared resources
# Afrikaans (True): wat is die kern gedeelte van n bedryfstelsel wat verantwoordelik is vir die beheer van die sve geheue en ander gedeelde hulpbronne
# Afrikaans (Predicted): wat die sentrale deel van n stelsel wat verantwoordelik is vir die nodige ruimte om die geheue en ander gemeenskaplike hulpbronne te verhoog <EOS>
#
# English: what is the main scheduling rule employed by the ratemonotonic scheduling scheme
# Afrikaans (True): wat is die hoof skeduleringreel wat gebruik word in die koersmonotoniese skeduleringskema
# Afrikaans (Predicted): what is die hoofkarakter wat deur die mark aangebied word sedert die le aanhaling help le aanhaling help word <EOS>
#
# English: describe the use of semaphores within an operating system
# Afrikaans (True): beskryf die gebruik van semafore in n bedryfstelsel
# Afrikaans (Predicted): as binne gebruik geneem uit wat deur n stelsel stelsel gebruik word <EOS>
#
# English: an operating system employs the earliestdeadlinefirst edf scheduling scheme and needs to execute three periodic processes defined in the table below
# Afrikaans (True): n bedryfstelsel maak gebruik van die vroegstespertydeerste vse skeduleringskema en word vereis om drie periodiese prosesse wat definieer is in die onderstaande tabel te verwerk
# Afrikaans (Predicted): n stel gebruik die maatskappy se vermo en n mens se eienskappe van die prosesse wat in die tabel hieronder gesien word <EOS>
#
# English: fill in the table provided and determine which process is executed within the cpu at each time quantum
# Afrikaans (True): voltooi die gegewe tabel en bepaal watter proses word uitgevoer binne die sve by elke tydkwantum
# Afrikaans (Predicted): n requiemmis van die en af wat binne die gebou is word in die gebou bewaar en is deel van ekosisteem <EOS>
#
# English: assume that all the processes starts at ttext s
# Afrikaans (True): aanvaar dat al die prosesse begin by t text s
# Afrikaans (Predicted): aanvaar dat alle prosesse by die betrokke begin s en s dat ongeveer tot die hele begin werk <EOS>
#
# English: what is the difference between the bigendian and littleendian formats
# Afrikaans (True): wat is die verskil tussen die textitbigendian en textitlittleendian formate
# Afrikaans (Predicted): die verskil tussen en is in die dood en word verhard <EOS>
#
# English: explain how three different aspects of accumulators used in the tic family of processors enable the tic to perform more efficient numerical computations
# Afrikaans (True): verduidelik hoe die verskillende aspekte van sommeerders gebruik in die tic familie van verwerker wat tot gevolg het dat die tic meer effektief numeriese operasies kan uitvoer
# Afrikaans (Predicted): voorheen drie verskillende aspekte van gebruik in die gesin van die rewolusie het die idee meer doeltreffend baie doeltreffend baie gebruik <EOS>
#
# English: you have a choice between the following processors armv ticxx and picfxx
# Afrikaans (True): jy het die keuse tussen die volgende verwerkers armv ticxx en picfxx
# Afrikaans (Predicted): het n keuse tussen die volgende efficient en bestaan uit te sluit <EOS>
#
# English: for each of the devices listed below indicate what will be your processor of choice in each case and give one processor characteristic motivating your choice
# Afrikaans (True): vir elk van hierdie toepassings in die onderstaande tabel wys watter verwerker die mees geskik is in elke toepassing en motiveer jou antwoord met een eienskap van die verwerker
# Afrikaans (Predicted): elkeen sal die droom van die gebruik van mondelinge tou wees of vir die wek daarvan verbeter en sodoende n moontlike eienskap byvoorbeeld die moontlike baba <EOS>
#
# English: below is a section of assembler code for the arm processor
# Afrikaans (True): n instruksielys van n armverwerker word gelys
# Afrikaans (Predicted): onder die gedeelte van die arm gedra <EOS>
#
# English: refer to the appendix for table with description of the arm assembler instructions
# Afrikaans (True): verwys na die bylae vir tabelle met beskrywing van die arm instruksies
# Afrikaans (Predicted): verwys na die la grande vir beskrywing van die armes maar die belangrikheid daarvan <EOS>
#
# English: write the equivalent block ccode
# Afrikaans (True): skryf die ekwivalente blok ckode
# Afrikaans (Predicted): die ekwivalent van die onderwerp is <EOS>
